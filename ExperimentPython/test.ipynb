# %%
from slmcontrol import *
from cameras.Ximea import XimeaCamera
from capture_utils import *
import numpy as np
import matplotlib.pyplot as plt
import h5py

x, y = build_grid(15.36, 8.64, 1920, 1080)
w = 0.3
incoming = hg(x, y, 0, 0, 2.3)
config = Config(incoming, x, y, 82,4,-3)

# %%
slm = SLMdisplay(monitor=1)

# %%
camera = XimeaCamera()
camera.camera.set_param("downsampling", "XI_DWN_2x2")
camera.camera.set_param("exposure", 15)
camera.camera.set_param("width", 200)
camera.camera.set_param("height", 200)
camera.camera.set_param("offsetX", 84)
camera.camera.set_param("offsetY", 236)

# %%
desired = hg(x, y, 5, 5, w)

# Generates the hologram that will be shown in the SLM
holo = generate_hologram(desired, incoming, x, y, 82, 4, -3, 0, 0)

# Displays the generated hologram
slm.updateArray(holo)

# %%
img = camera.capture()
print(img.max())
plt.imshow(img)
# Out:
# 222

# %%
#camera.close()

# %%
basis = np.stack([lg(x,y,1,0,w), lg(x,y,0,2,w)])

with h5py.File("../Data/template.h5") as file:
    rhos = file["labels_dim2"][:50]

mean_imgs = np.empty((rhos.shape[0], 200, 200), dtype=np.uint8)

# %%
basis_loop(mean_imgs, 300, basis, rhos,
    camera, slm, config, sleep_time=0.0)
# Out:
# Capturing mode  1
# 100%|██████████| 299/299 [00:42<00:00,  7.03it/s]
# Capturing mode  2
# 100%|██████████| 299/299 [00:37<00:00,  7.88it/s]
# Capturing mode  3
# 100%|██████████| 299/299 [00:37<00:00,  7.95it/s]
# Capturing mode  4
# 100%|██████████| 299/299 [00:37<00:00,  7.97it/s]
# Capturing mode  5
# 100%|██████████| 299/299 [00:37<00:00,  7.95it/s]
# Capturing mode  6
# 100%|██████████| 299/299 [00:37<00:00,  7.96it/s]
# Capturing mode  7
# 100%|██████████| 299/299 [00:38<00:00,  7.68it/s]
# Capturing mode  8
# 100%|██████████| 299/299 [00:37<00:00,  7.90it/s]
# Capturing mode  9
# 100%|██████████| 299/299 [00:37<00:00,  8.01it/s]
# Capturing mode  10
# 100%|██████████| 299/299 [00:37<00:00,  7.99it/s]
# Capturing mode  11
# 100%|██████████| 299/299 [00:37<00:00,  8.01it/s]
# Capturing mode  12
# 100%|██████████| 299/299 [00:37<00:00,  7.95it/s]
# Capturing mode  13
# 100%|██████████| 299/299 [00:37<00:00,  8.01it/s]
# Capturing mode  14
# 100%|██████████| 299/299 [00:37<00:00,  8.04it/s]
# Capturing mode  15
# 100%|██████████| 299/299 [00:37<00:00,  8.03it/s]
# Capturing mode  16
# 100%|██████████| 299/299 [00:37<00:00,  8.04it/s]
# Capturing mode  17
# 100%|██████████| 299/299 [00:37<00:00,  8.05it/s]
# Capturing mode  18
# 100%|██████████| 299/299 [00:37<00:00,  8.04it/s]
# Capturing mode  19
# 100%|██████████| 299/299 [00:37<00:00,  8.03it/s]
# Capturing mode  20
# 100%|██████████| 299/299 [00:37<00:00,  8.06it/s]
# Capturing mode  21
# 100%|██████████| 299/299 [00:37<00:00,  8.06it/s]
# Capturing mode  22
# 100%|██████████| 299/299 [00:37<00:00,  8.06it/s]
# Capturing mode  23
# 100%|██████████| 299/299 [00:37<00:00,  8.08it/s]
# Capturing mode  24
# 100%|██████████| 299/299 [00:37<00:00,  8.02it/s]
# Capturing mode  25
# 100%|██████████| 299/299 [00:37<00:00,  7.95it/s]
# Capturing mode  26
# 100%|██████████| 299/299 [00:37<00:00,  8.01it/s]
# Capturing mode  27
# 100%|██████████| 299/299 [00:37<00:00,  7.94it/s]
# Capturing mode  28
# 100%|██████████| 299/299 [00:37<00:00,  7.94it/s]
# Capturing mode  29
# 100%|██████████| 299/299 [00:37<00:00,  8.02it/s]
# Capturing mode  30
# 100%|██████████| 299/299 [00:39<00:00,  7.58it/s]
# Capturing mode  31
# 100%|██████████| 299/299 [00:37<00:00,  8.01it/s]
# Capturing mode  32
# 100%|██████████| 299/299 [00:37<00:00,  8.02it/s]
# Capturing mode  33
# 100%|██████████| 299/299 [00:37<00:00,  8.01it/s]
# Capturing mode  34
# 100%|██████████| 299/299 [00:37<00:00,  8.02it/s]
# Capturing mode  35
# 100%|██████████| 299/299 [00:37<00:00,  8.00it/s]
# Capturing mode  36
# 100%|██████████| 299/299 [00:37<00:00,  7.98it/s]
# Capturing mode  37
# 100%|██████████| 299/299 [00:37<00:00,  7.99it/s]
# Capturing mode  38
# 100%|██████████| 299/299 [00:37<00:00,  7.99it/s]
# Capturing mode  39
# 100%|██████████| 299/299 [00:38<00:00,  7.81it/s]
# Capturing mode  40
# 100%|██████████| 299/299 [00:37<00:00,  7.88it/s]
# Capturing mode  41
# 100%|██████████| 299/299 [00:37<00:00,  8.00it/s]
# Capturing mode  42
# 100%|██████████| 299/299 [00:37<00:00,  7.98it/s]
# Capturing mode  43
# 100%|██████████| 299/299 [00:37<00:00,  7.97it/s]
# Capturing mode  44
# 100%|██████████| 299/299 [00:37<00:00,  8.01it/s]
# Capturing mode  45
# 100%|██████████| 299/299 [00:37<00:00,  7.97it/s]
# Capturing mode  46
# 100%|██████████| 299/299 [00:38<00:00,  7.74it/s]
# Capturing mode  47
# 100%|██████████| 299/299 [00:38<00:00,  7.83it/s]
# Capturing mode  48
# 100%|██████████| 299/299 [00:38<00:00,  7.87it/s]
# Capturing mode  49
# 100%|██████████| 299/299 [00:37<00:00,  7.87it/s]
# Capturing mode  50
# 100%|██████████| 299/299 [00:37<00:00,  8.00it/s]

# %%
img_plot = mean_imgs[0]

plt.imshow(img_plot, cmap='jet')

# %%
with h5py.File("../Data/Raw/test_python_2.h5", 'a') as file:
    file["images_1"] = mean_imgs
    file["images_1"].attrs["density_matrices"] = rhos

# %%
with h5py.File("../Data/Raw/test_python_2.h5", 'a') as file:
    desired = hg(x, y, 0, 0, w)
    holo = generate_hologram(desired, incoming, x, y, 82, 4, -3, 0, 0)
    slm.updateArray(holo,1)
    file["calibration"] = camera.capture()
