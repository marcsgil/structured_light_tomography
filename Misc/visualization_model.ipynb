# %%
from torchview import draw_graph
import sys
sys.path.append('/home/marcsgil/Desktop/structured_light_tomography/Tomography/MachineLearning/')
import models

import graphviz
graphviz.set_jupyter_format('png')
# Out:
# 'svg'

# %%
model = models.DefaultConvNet(64,64,2,3)
# device='meta' -> no memory is consumed for visualization
model_graph = draw_graph(model, input_size=(256, 2, 64,64), device='meta')
model_graph.visual_graph

# %%
pwd()
