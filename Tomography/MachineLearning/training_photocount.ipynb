# %%
import torch
from torch import nn
from torch.optim import lr_scheduler
from torch.utils.data import DataLoader, TensorDataset
from torch.utils.tensorboard import SummaryWriter
import models
import training
from torchvision.transforms import v2
import numpy as np
import matplotlib.pyplot as plts
from os.path import join
import torchvision
import torch.nn.functional as F
import h5py
import matplotlib.pyplot as plt
from torch.utils.data import random_split

device = ("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using {device} device")

def format_data(x):
    mean = [x[:, n, :, :].mean() for n in range(x.shape[1])]
    std = [x[:, n, :, :].std() for n in range(x.shape[1])]

    X = v2.Compose([
            torch.from_numpy,
            v2.Normalize(mean=mean, std=std),
            v2.Resize((64, 64)),
        ])(x).to(device)
    return X
# Out:
# Using cuda device

# %%
orders = range(4,5)
photocounts = [2**i for i in range(6, 12)]

for order in orders:
    for n in photocounts:
        with h5py.File('../../Data/Training/pure_photocount.h5', 'r') as f:
            images = format_data(f[f'images_order{order}/{n}_photocounts'][:])
            labels = torch.from_numpy(f[f'labels_order{order}/{n}_photocounts'][:]).to(device)

        dset = TensorDataset(images,labels)

        train_size = int(0.85 * len(dset))
        test_size = len(dset) - train_size

        train_dataset, test_dataset = random_split(dset, [train_size, test_size])
        train_loader = DataLoader(train_dataset, batch_size=256, shuffle=True)
        test_loader = DataLoader(test_dataset, batch_size=256)

        L = images.shape[2]
        loss_fn = training.fidelity_loss
        n_channels = 2
        n_classes = 2*(order+1)

        model = models.ConvNet(L,L,n_channels, n_classes,[24,40,35],5,nn.ELU,[120,80,40]).to(device)

        optimizer = torch.optim.Adam(model.parameters(), amsgrad=True)
        scheduler = lr_scheduler.ReduceLROnPlateau(optimizer, patience=10, factor=.5, min_lr = 1e-5)

        save_path = f"../../Results/MachineLearningModels/Photocount/Pure_Order{order}/{n}_photocounts"

        writer = SummaryWriter(save_path)
        early_stopping = training.EarlyStopping(patience=30,save_path=save_path)
        for t in range(200):
            epoch = t+1
            print(f"-------------------------------\nEpoch {epoch}")
            training.train(model, train_loader, loss_fn, optimizer, device)
            val_loss = training.test(model, test_loader, loss_fn, device, epoch, writer, verbose=True)
            scheduler.step(val_loss)
            early_stopping(val_loss, model)

            if early_stopping.early_stop:
                print("Early stopping")
                break
        print("Done!")
        writer.close()
# Out:
# -------------------------------
# Epoch 1
# Training loss: 0.36980126
# -------------------------------
# Epoch 2
# Training loss: 0.31751469
# -------------------------------
# Epoch 3
# Training loss: 0.30374380
# -------------------------------
# Epoch 4
# Training loss: 0.28351329
# -------------------------------
# Epoch 5
# Training loss: 0.27638213
# -------------------------------
# Epoch 6
# Training loss: 0.27152120
# -------------------------------
# Epoch 7
# Training loss: 0.27003145
# -------------------------------
# Epoch 8
# Training loss: 0.25839978
# -------------------------------
# Epoch 9
# Training loss: 0.25717710
# -------------------------------
# Epoch 10
# Training loss: 0.25301319
# -------------------------------
# Epoch 11
# Training loss: 0.25062973
# -------------------------------
# Epoch 12
# Training loss: 0.25013929
# -------------------------------
# Epoch 13
# Training loss: 0.25120283
# -------------------------------
# Epoch 14
# Training loss: 0.24762631
# -------------------------------
# Epoch 15
# Training loss: 0.24716482
# -------------------------------
# Epoch 16
# Training loss: 0.24769216
# -------------------------------
# Epoch 17
# Training loss: 0.24912372
# -------------------------------
# Epoch 18
# Training loss: 0.24766342
# -------------------------------
# Epoch 19
# Training loss: 0.24721034
# -------------------------------
# Epoch 20
# Training loss: 0.24618241
# -------------------------------
# Epoch 21
# Training loss: 0.24718533
# -------------------------------
# Epoch 22
# Training loss: 0.24775994
# -------------------------------
# Epoch 23
# Training loss: 0.24711427
# -------------------------------
# Epoch 24
# Training loss: 0.24843767
# -------------------------------
# Epoch 25
# Training loss: 0.24793806
# -------------------------------
# Epoch 26
# Training loss: 0.24849894
# -------------------------------
# Epoch 27
# Training loss: 0.24999992
# -------------------------------
# Epoch 28
# Training loss: 0.25004793
# -------------------------------
# Epoch 29
# Training loss: 0.24898604
# -------------------------------
# Epoch 30
# Training loss: 0.25037294
# -------------------------------
# Epoch 31
# Training loss: 0.25100836
# -------------------------------
# Epoch 32
# Training loss: 0.24929346
# -------------------------------
# Epoch 33
# Training loss: 0.24932500
# -------------------------------
# Epoch 34
# Training loss: 0.25052178
# -------------------------------
# Epoch 35
# Training loss: 0.25163318
# -------------------------------
# Epoch 36
# Training loss: 0.25140172
# -------------------------------
# Epoch 37
# Training loss: 0.25209969
# -------------------------------
# Epoch 38
# Training loss: 0.25240827
# -------------------------------
# Epoch 39
# Training loss: 0.25316830
# -------------------------------
# Epoch 40
# Training loss: 0.25315866
# -------------------------------
# Epoch 41
# Training loss: 0.25333159
# -------------------------------
# Epoch 42
# Training loss: 0.25448287
# -------------------------------
# Epoch 43
# Training loss: 0.25388433
# -------------------------------
# Epoch 44
# Training loss: 0.25418568
# -------------------------------
# Epoch 45
# Training loss: 0.25457440
# -------------------------------
# Epoch 46
# Training loss: 0.25549295
# -------------------------------
# Epoch 47
# Training loss: 0.25520360
# -------------------------------
# Epoch 48
# Training loss: 0.25545306
# -------------------------------
# Epoch 49
# Training loss: 0.25604596
# -------------------------------
# Epoch 50
# Training loss: 0.25592442
# Early stopping
# Done!
# -------------------------------
# Epoch 1
# Training loss: 0.26241350
# -------------------------------
# Epoch 2
# Training loss: 0.22105977
# -------------------------------
# Epoch 3
# Training loss: 0.19492087
# -------------------------------
# Epoch 4
# Training loss: 0.18248203
# -------------------------------
# Epoch 5
# Training loss: 0.16978840
# -------------------------------
# Epoch 6
# Training loss: 0.16744031
# -------------------------------
# Epoch 7
# Training loss: 0.16047250
# -------------------------------
# Epoch 8
# Training loss: 0.15579953
# -------------------------------
# Epoch 9
# Training loss: 0.15550805
# -------------------------------
# Epoch 10
# Training loss: 0.15291779
# -------------------------------
# Epoch 11
# Training loss: 0.15052678
# -------------------------------
# Epoch 12
# Training loss: 0.14890804
# -------------------------------
# Epoch 13
# Training loss: 0.14763436
# -------------------------------
# Epoch 14
# Training loss: 0.14723985
# -------------------------------
# Epoch 15
# Training loss: 0.14597431
# -------------------------------
# Epoch 16
# Training loss: 0.14492393
# -------------------------------
# Epoch 17
# Training loss: 0.14553318
# -------------------------------
# Epoch 18
# Training loss: 0.14555658
# -------------------------------
# Epoch 19
# Training loss: 0.14397455
# -------------------------------
# Epoch 20
# Training loss: 0.14552769
# -------------------------------
# Epoch 21
# Training loss: 0.14374296
# -------------------------------
# Epoch 22
# Training loss: 0.14339461
# -------------------------------
# Epoch 23
# Training loss: 0.14423721
# -------------------------------
# Epoch 24
# Training loss: 0.14428335
# -------------------------------
# Epoch 25
# Training loss: 0.14430752
# -------------------------------
# Epoch 26
# Training loss: 0.14428661
# -------------------------------
# Epoch 27
# Training loss: 0.14387060
# -------------------------------
# Epoch 28
# Training loss: 0.14425813
# -------------------------------
# Epoch 29
# Training loss: 0.14345186
# -------------------------------
# Epoch 30
# Training loss: 0.14363726
# -------------------------------
# Epoch 31
# Training loss: 0.14503706
# -------------------------------
# Epoch 32
# Training loss: 0.14439591
# -------------------------------
# Epoch 33
# Training loss: 0.14441469
# -------------------------------
# Epoch 34
# Training loss: 0.14207353
# -------------------------------
# Epoch 35
# Training loss: 0.14251252
# -------------------------------
# Epoch 36
# Training loss: 0.14268666
# -------------------------------
# Epoch 37
# Training loss: 0.14297346
# -------------------------------
# Epoch 38
# Training loss: 0.14380505
# -------------------------------
# Epoch 39
# Training loss: 0.14363445
# -------------------------------
# Epoch 40
# Training loss: 0.14386707
# -------------------------------
# Epoch 41
# Training loss: 0.14424573
# -------------------------------
# Epoch 42
# Training loss: 0.14361593
# -------------------------------
# Epoch 43
# Training loss: 0.14453627
# -------------------------------
# Epoch 44
# Training loss: 0.14450385
# -------------------------------
# Epoch 45
# Training loss: 0.14489428
# -------------------------------
# Epoch 46
# Training loss: 0.14423147
# -------------------------------
# Epoch 47
# Training loss: 0.14411852
# -------------------------------
# Epoch 48
# Training loss: 0.14422191
# -------------------------------
# Epoch 49
# Training loss: 0.14441989
# -------------------------------
# Epoch 50
# Training loss: 0.14453120
# -------------------------------
# Epoch 51
# Training loss: 0.14491168
# -------------------------------
# Epoch 52
# Training loss: 0.14481333
# -------------------------------
# Epoch 53
# Training loss: 0.14476038
# -------------------------------
# Epoch 54
# Training loss: 0.14520832
# -------------------------------
# Epoch 55
# Training loss: 0.14512824
# -------------------------------
# Epoch 56
# Training loss: 0.14567889
# -------------------------------
# Epoch 57
# Training loss: 0.14500012
# -------------------------------
# Epoch 58
# Training loss: 0.14523948
# -------------------------------
# Epoch 59
# Training loss: 0.14534768
# -------------------------------
# Epoch 60
# Training loss: 0.14538907
# -------------------------------
# Epoch 61
# Training loss: 0.14525765
# -------------------------------
# Epoch 62
# Training loss: 0.14577071
# -------------------------------
# Epoch 63
# Training loss: 0.14571974
# -------------------------------
# Epoch 64
# Training loss: 0.14575609
# Early stopping
# Done!
# -------------------------------
# Epoch 1
# Training loss: 0.20575375
# -------------------------------
# Epoch 2
# Training loss: 0.15655667
# -------------------------------
# Epoch 3
# Training loss: 0.12897336
# -------------------------------
# Epoch 4
# Training loss: 0.11826280
# -------------------------------
# Epoch 5
# Training loss: 0.10995624
# -------------------------------
# Epoch 6
# Training loss: 0.10362957
# -------------------------------
# Epoch 7
# Training loss: 0.10078765
# -------------------------------
# Epoch 8
# Training loss: 0.09675897
# -------------------------------
# Epoch 9
# Training loss: 0.09513756
# -------------------------------
# Epoch 10
# Training loss: 0.09363150
# -------------------------------
# Epoch 11
# Training loss: 0.09045676
# -------------------------------
# Epoch 12
# Training loss: 0.08947719
# -------------------------------
# Epoch 13
# Training loss: 0.08829018
# -------------------------------
# Epoch 14
# Training loss: 0.08705747
# -------------------------------
# Epoch 15
# Training loss: 0.08612818
# -------------------------------
# Epoch 16
# Training loss: 0.08624732
# -------------------------------
# Epoch 17
# Training loss: 0.08552424
# -------------------------------
# Epoch 18
# Training loss: 0.08581932
# -------------------------------
# Epoch 19
# Training loss: 0.08652277
# -------------------------------
# Epoch 20
# Training loss: 0.08421416
# -------------------------------
# Epoch 21
# Training loss: 0.08310165
# -------------------------------
# Epoch 22
# Training loss: 0.08283909
# -------------------------------
# Epoch 23
# Training loss: 0.08364908
# -------------------------------
# Epoch 24
# Training loss: 0.08347601
# -------------------------------
# Epoch 25
# Training loss: 0.08265371
# -------------------------------
# Epoch 26
# Training loss: 0.08355725
# -------------------------------
# Epoch 27
# Training loss: 0.08202495
# -------------------------------
# Epoch 28
# Training loss: 0.08323272
# -------------------------------
# Epoch 29
# Training loss: 0.08225237
# -------------------------------
# Epoch 30
# Training loss: 0.08268947
# -------------------------------
# Epoch 31
# Training loss: 0.08312641
# -------------------------------
# Epoch 32
# Training loss: 0.08166722
# -------------------------------
# Epoch 33
# Training loss: 0.08148203
# -------------------------------
# Epoch 34
# Training loss: 0.08180312
# -------------------------------
# Epoch 35
# Training loss: 0.08171819
# -------------------------------
# Epoch 36
# Training loss: 0.08169437
# -------------------------------
# Epoch 37
# Training loss: 0.08229926
# -------------------------------
# Epoch 38
# Training loss: 0.08191075
# -------------------------------
# Epoch 39
# Training loss: 0.08206081
# -------------------------------
# Epoch 40
# Training loss: 0.08219658
# -------------------------------
# Epoch 41
# Training loss: 0.08247876
# -------------------------------
# Epoch 42
# Training loss: 0.08222420
# -------------------------------
# Epoch 43
# Training loss: 0.08165801
# -------------------------------
# Epoch 44
# Training loss: 0.08189998
# -------------------------------
# Epoch 45
# Training loss: 0.08080245
# -------------------------------
# Epoch 46
# Training loss: 0.08073463
# -------------------------------
# Epoch 47
# Training loss: 0.08073601
# -------------------------------
# Epoch 48
# Training loss: 0.08058667
# -------------------------------
# Epoch 49
# Training loss: 0.08107006
# -------------------------------
# Epoch 50
# Training loss: 0.08115914
# -------------------------------
# Epoch 51
# Training loss: 0.08122074
# -------------------------------
# Epoch 52
# Training loss: 0.08118904
# -------------------------------
# Epoch 53
# Training loss: 0.08111457
# -------------------------------
# Epoch 54
# Training loss: 0.08157754
# -------------------------------
# Epoch 55
# Training loss: 0.08152793
# -------------------------------
# Epoch 56
# Training loss: 0.08164196
# -------------------------------
# Epoch 57
# Training loss: 0.08137420
# -------------------------------
# Epoch 58
# Training loss: 0.08155296
# -------------------------------
# Epoch 59
# Training loss: 0.08175444
# -------------------------------
# Epoch 60
# Training loss: 0.08108700
# -------------------------------
# Epoch 61
# Training loss: 0.08123188
# -------------------------------
# Epoch 62
# Training loss: 0.08112374
# -------------------------------
# Epoch 63
# Training loss: 0.08119273
# -------------------------------
# Epoch 64
# Training loss: 0.08144660
# -------------------------------
# Epoch 65
# Training loss: 0.08138132
# -------------------------------
# Epoch 66
# Training loss: 0.08154617
# -------------------------------
# Epoch 67
# Training loss: 0.08167214
# -------------------------------
# Epoch 68
# Training loss: 0.08178143
# -------------------------------
# Epoch 69
# Training loss: 0.08165267
# -------------------------------
# Epoch 70
# Training loss: 0.08156340
# -------------------------------
# Epoch 71
# Training loss: 0.08146706
# -------------------------------
# Epoch 72
# Training loss: 0.08142455
# -------------------------------
# Epoch 73
# Training loss: 0.08156124
# -------------------------------
# Epoch 74
# Training loss: 0.08152351
# -------------------------------
# Epoch 75
# Training loss: 0.08158709
# -------------------------------
# Epoch 76
# Training loss: 0.08162630
# -------------------------------
# Epoch 77
# Training loss: 0.08154393
# -------------------------------
# Epoch 78
# Training loss: 0.08163008
# Early stopping
# Done!
# -------------------------------
# Epoch 1
# Training loss: 0.13958020
# -------------------------------
# Epoch 2
# Training loss: 0.10173287
# -------------------------------
# Epoch 3
# Training loss: 0.08952949
# -------------------------------
# Epoch 4
# Training loss: 0.08639022
# -------------------------------
# Epoch 5
# Training loss: 0.08023644
# -------------------------------
# Epoch 6
# Training loss: 0.06735668
# -------------------------------
# Epoch 7
# Training loss: 0.06397437
# -------------------------------
# Epoch 8
# Training loss: 0.06712493
# -------------------------------
# Epoch 9
# Training loss: 0.05911366
# -------------------------------
# Epoch 10
# Training loss: 0.05642306
# -------------------------------
# Epoch 11
# Training loss: 0.05605589
# -------------------------------
# Epoch 12
# Training loss: 0.05552617
# -------------------------------
# Epoch 13
# Training loss: 0.05477021
# -------------------------------
# Epoch 14
# Training loss: 0.05423734
# -------------------------------
# Epoch 15
# Training loss: 0.05240140
# -------------------------------
# Epoch 16
# Training loss: 0.05183798
# -------------------------------
# Epoch 17
# Training loss: 0.05049859
# -------------------------------
# Epoch 18
# Training loss: 0.05101848
# -------------------------------
# Epoch 19
# Training loss: 0.04965015
# -------------------------------
# Epoch 20
# Training loss: 0.04999593
# -------------------------------
# Epoch 21
# Training loss: 0.05079472
# -------------------------------
# Epoch 22
# Training loss: 0.04936285
# -------------------------------
# Epoch 23
# Training loss: 0.04918432
# -------------------------------
# Epoch 24
# Training loss: 0.04900815
# -------------------------------
# Epoch 25
# Training loss: 0.04834866
# -------------------------------
# Epoch 26
# Training loss: 0.04823135
# -------------------------------
# Epoch 27
# Training loss: 0.04744456
# -------------------------------
# Epoch 28
# Training loss: 0.04840760
# -------------------------------
# Epoch 29
# Training loss: 0.04826006
# -------------------------------
# Epoch 30
# Training loss: 0.04823055
# -------------------------------
# Epoch 31
# Training loss: 0.04739772
# -------------------------------
# Epoch 32
# Training loss: 0.04777678
# -------------------------------
# Epoch 33
# Training loss: 0.04763519
# -------------------------------
# Epoch 34
# Training loss: 0.04737604
# -------------------------------
# Epoch 35
# Training loss: 0.04755228
# -------------------------------
# Epoch 36
# Training loss: 0.04717696
# -------------------------------
# Epoch 37
# Training loss: 0.04694241
# -------------------------------
# Epoch 38
# Training loss: 0.04744969
# -------------------------------
# Epoch 39
# Training loss: 0.04693195
# -------------------------------
# Epoch 40
# Training loss: 0.04652116
# -------------------------------
# Epoch 41
# Training loss: 0.04713020
# -------------------------------
# Epoch 42
# Training loss: 0.04816059
# -------------------------------
# Epoch 43
# Training loss: 0.04672361
# -------------------------------
# Epoch 44
# Training loss: 0.04744136
# -------------------------------
# Epoch 45
# Training loss: 0.04656270
# -------------------------------
# Epoch 46
# Training loss: 0.04670456
# -------------------------------
# Epoch 47
# Training loss: 0.04647838
# -------------------------------
# Epoch 48
# Training loss: 0.04665143
# -------------------------------
# Epoch 49
# Training loss: 0.04645048
# -------------------------------
# Epoch 50
# Training loss: 0.04685006
# -------------------------------
# Epoch 51
# Training loss: 0.04622947
# -------------------------------
# Epoch 52
# Training loss: 0.04618391
# -------------------------------
# Epoch 53
# Training loss: 0.04638317
# -------------------------------
# Epoch 54
# Training loss: 0.04670156
# -------------------------------
# Epoch 55
# Training loss: 0.04574955
# -------------------------------
# Epoch 56
# Training loss: 0.04641564
# -------------------------------
# Epoch 57
# Training loss: 0.04644416
# -------------------------------
# Epoch 58
# Training loss: 0.04664738
# -------------------------------
# Epoch 59
# Training loss: 0.04625955
# -------------------------------
# Epoch 60
# Training loss: 0.04680015
# -------------------------------
# Epoch 61
# Training loss: 0.04655428
# -------------------------------
# Epoch 62
# Training loss: 0.04630142
# -------------------------------
# Epoch 63
# Training loss: 0.04667247
# -------------------------------
# Epoch 64
# Training loss: 0.04618297
# -------------------------------
# Epoch 65
# Training loss: 0.04576725
# -------------------------------
# Epoch 66
# Training loss: 0.04672362
# -------------------------------
# Epoch 67
# Training loss: 0.04499109
# -------------------------------
# Epoch 68
# Training loss: 0.04511285
# -------------------------------
# Epoch 69
# Training loss: 0.04517662
# -------------------------------
# Epoch 70
# Training loss: 0.04524175
# -------------------------------
# Epoch 71
# Training loss: 0.04534234
# -------------------------------
# Epoch 72
# Training loss: 0.04541998
# -------------------------------
# Epoch 73
# Training loss: 0.04511603
# -------------------------------
# Epoch 74
# Training loss: 0.04518077
# -------------------------------
# Epoch 75
# Training loss: 0.04552943
# -------------------------------
# Epoch 76
# Training loss: 0.04536043
# -------------------------------
# Epoch 77
# Training loss: 0.04527325
# -------------------------------
# Epoch 78
# Training loss: 0.04531738
# -------------------------------
# Epoch 79
# Training loss: 0.04495540
# -------------------------------
# Epoch 80
# Training loss: 0.04493324
# -------------------------------
# Epoch 81
# Training loss: 0.04495742
# -------------------------------
# Epoch 82
# Training loss: 0.04493632
# -------------------------------
# Epoch 83
# Training loss: 0.04493671
# -------------------------------
# Epoch 84
# Training loss: 0.04505378
# -------------------------------
# Epoch 85
# Training loss: 0.04495608
# -------------------------------
# Epoch 86
# Training loss: 0.04493481
# -------------------------------
# Epoch 87
# Training loss: 0.04499650
# -------------------------------
# Epoch 88
# Training loss: 0.04496591
# -------------------------------
# Epoch 89
# Training loss: 0.04505939
# -------------------------------
# Epoch 90
# Training loss: 0.04508636
# -------------------------------
# Epoch 91
# Training loss: 0.04525392
# -------------------------------
# Epoch 92
# Training loss: 0.04486228
# -------------------------------
# Epoch 93
# Training loss: 0.04495040
# -------------------------------
# Epoch 94
# Training loss: 0.04497198
# -------------------------------
# Epoch 95
# Training loss: 0.04495263
# -------------------------------
# Epoch 96
# Training loss: 0.04495053
# -------------------------------
# Epoch 97
# Training loss: 0.04494188
# -------------------------------
# Epoch 98
# Training loss: 0.04494171
# -------------------------------
# Epoch 99
# Training loss: 0.04496965
# -------------------------------
# Epoch 100
# Training loss: 0.04498021
# -------------------------------
# Epoch 101
# Training loss: 0.04494237
# -------------------------------
# Epoch 102
# Training loss: 0.04501596
# -------------------------------
# Epoch 103
# Training loss: 0.04494653
# -------------------------------
# Epoch 104
# Training loss: 0.04490939
# -------------------------------
# Epoch 105
# Training loss: 0.04488141
# -------------------------------
# Epoch 106
# Training loss: 0.04493190
# -------------------------------
# Epoch 107
# Training loss: 0.04496931
# -------------------------------
# Epoch 108
# Training loss: 0.04494348
# -------------------------------
# Epoch 109
# Training loss: 0.04495851
# -------------------------------
# Epoch 110
# Training loss: 0.04494610
# -------------------------------
# Epoch 111
# Training loss: 0.04494913
# -------------------------------
# Epoch 112
# Training loss: 0.04495845
# -------------------------------
# Epoch 113
# Training loss: 0.04498154
# -------------------------------
# Epoch 114
# Training loss: 0.04495503
# -------------------------------
# Epoch 115
# Training loss: 0.04491110
# -------------------------------
# Epoch 116
# Training loss: 0.04495045
# -------------------------------
# Epoch 117
# Training loss: 0.04491492
# -------------------------------
# Epoch 118
# Training loss: 0.04490668
# -------------------------------
# Epoch 119
# Training loss: 0.04492537
# -------------------------------
# Epoch 120
# Training loss: 0.04494180
# -------------------------------
# Epoch 121
# Training loss: 0.04492812
# -------------------------------
# Epoch 122
# Training loss: 0.04492474
# Early stopping
# Done!
# -------------------------------
# Epoch 1
# Training loss: 0.11774712
# -------------------------------
# Epoch 2
# Training loss: 0.07877516
# -------------------------------
# Epoch 3
# Training loss: 0.06348859
# -------------------------------
# Epoch 4
# Training loss: 0.05587895
# -------------------------------
# Epoch 5
# Training loss: 0.05208039
# -------------------------------
# Epoch 6
# Training loss: 0.04696831
# -------------------------------
# Epoch 7
# Training loss: 0.04454346
# -------------------------------
# Epoch 8
# Training loss: 0.04158466
# -------------------------------
# Epoch 9
# Training loss: 0.03994278
# -------------------------------
# Epoch 10
# Training loss: 0.03873881
# -------------------------------
# Epoch 11
# Training loss: 0.04287579
# -------------------------------
# Epoch 12
# Training loss: 0.03648494
# -------------------------------
# Epoch 13
# Training loss: 0.03606146
# -------------------------------
# Epoch 14
# Training loss: 0.03585874
# -------------------------------
# Epoch 15
# Training loss: 0.03514880
# -------------------------------
# Epoch 16
# Training loss: 0.03422573
# -------------------------------
# Epoch 17
# Training loss: 0.03365894
# -------------------------------
# Epoch 18
# Training loss: 0.03328391
# -------------------------------
# Epoch 19
# Training loss: 0.03280678
# -------------------------------
# Epoch 20
# Training loss: 0.03223359
# -------------------------------
# Epoch 21
# Training loss: 0.03261029
# -------------------------------
# Epoch 22
# Training loss: 0.03276609
# -------------------------------
# Epoch 23
# Training loss: 0.03199146
# -------------------------------
# Epoch 24
# Training loss: 0.03223539
# -------------------------------
# Epoch 25
# Training loss: 0.03160760
# -------------------------------
# Epoch 26
# Training loss: 0.03132290
# -------------------------------
# Epoch 27
# Training loss: 0.03126053
# -------------------------------
# Epoch 28
# Training loss: 0.03116239
# -------------------------------
# Epoch 29
# Training loss: 0.03113310
# -------------------------------
# Epoch 30
# Training loss: 0.03163950
# -------------------------------
# Epoch 31
# Training loss: 0.03104840
# -------------------------------
# Epoch 32
# Training loss: 0.03077708
# -------------------------------
# Epoch 33
# Training loss: 0.03042600
# -------------------------------
# Epoch 34
# Training loss: 0.03001942
# -------------------------------
# Epoch 35
# Training loss: 0.03040445
# -------------------------------
# Epoch 36
# Training loss: 0.02973627
# -------------------------------
# Epoch 37
# Training loss: 0.02969452
# -------------------------------
# Epoch 38
# Training loss: 0.03009607
# -------------------------------
# Epoch 39
# Training loss: 0.03019350
# -------------------------------
# Epoch 40
# Training loss: 0.02969145
# -------------------------------
# Epoch 41
# Training loss: 0.02993616
# -------------------------------
# Epoch 42
# Training loss: 0.02956540
# -------------------------------
# Epoch 43
# Training loss: 0.02939089
# -------------------------------
# Epoch 44
# Training loss: 0.02948137
# -------------------------------
# Epoch 45
# Training loss: 0.02926049
# -------------------------------
# Epoch 46
# Training loss: 0.02955370
# -------------------------------
# Epoch 47
# Training loss: 0.02949446
# -------------------------------
# Epoch 48
# Training loss: 0.02941174
# -------------------------------
# Epoch 49
# Training loss: 0.02900200
# -------------------------------
# Epoch 50
# Training loss: 0.02901850
# -------------------------------
# Epoch 51
# Training loss: 0.02902300
# -------------------------------
# Epoch 52
# Training loss: 0.02900573
# -------------------------------
# Epoch 53
# Training loss: 0.02883113
# -------------------------------
# Epoch 54
# Training loss: 0.02881380
# -------------------------------
# Epoch 55
# Training loss: 0.02922291
# -------------------------------
# Epoch 56
# Training loss: 0.02879466
# -------------------------------
# Epoch 57
# Training loss: 0.02933621
# -------------------------------
# Epoch 58
# Training loss: 0.02912315
# -------------------------------
# Epoch 59
# Training loss: 0.02950118
# -------------------------------
# Epoch 60
# Training loss: 0.02844662
# -------------------------------
# Epoch 61
# Training loss: 0.02862148
# -------------------------------
# Epoch 62
# Training loss: 0.02850481
# -------------------------------
# Epoch 63
# Training loss: 0.02885744
# -------------------------------
# Epoch 64
# Training loss: 0.02863929
# -------------------------------
# Epoch 65
# Training loss: 0.02816975
# -------------------------------
# Epoch 66
# Training loss: 0.02883369
# -------------------------------
# Epoch 67
# Training loss: 0.02900906
# -------------------------------
# Epoch 68
# Training loss: 0.02870418
# -------------------------------
# Epoch 69
# Training loss: 0.02846913
# -------------------------------
# Epoch 70
# Training loss: 0.02925376
# -------------------------------
# Epoch 71
# Training loss: 0.02886628
# -------------------------------
# Epoch 72
# Training loss: 0.02861487
# -------------------------------
# Epoch 73
# Training loss: 0.02861797
# -------------------------------
# Epoch 74
# Training loss: 0.02843486
# -------------------------------
# Epoch 75
# Training loss: 0.02860145
# -------------------------------
# Epoch 76
# Training loss: 0.02835277
# -------------------------------
# Epoch 77
# Training loss: 0.02778783
# -------------------------------
# Epoch 78
# Training loss: 0.02769928
# -------------------------------
# Epoch 79
# Training loss: 0.02776167
# -------------------------------
# Epoch 80
# Training loss: 0.02782567
# -------------------------------
# Epoch 81
# Training loss: 0.02768396
# -------------------------------
# Epoch 82
# Training loss: 0.02777462
# -------------------------------
# Epoch 83
# Training loss: 0.02782223
# -------------------------------
# Epoch 84
# Training loss: 0.02790218
# -------------------------------
# Epoch 85
# Training loss: 0.02773205
# -------------------------------
# Epoch 86
# Training loss: 0.02770955
# -------------------------------
# Epoch 87
# Training loss: 0.02780497
# -------------------------------
# Epoch 88
# Training loss: 0.02793676
# -------------------------------
# Epoch 89
# Training loss: 0.02776760
# -------------------------------
# Epoch 90
# Training loss: 0.02775329
# -------------------------------
# Epoch 91
# Training loss: 0.02768591
# -------------------------------
# Epoch 92
# Training loss: 0.02784984
# -------------------------------
# Epoch 93
# Training loss: 0.02735519
# -------------------------------
# Epoch 94
# Training loss: 0.02738050
# -------------------------------
# Epoch 95
# Training loss: 0.02743824
# -------------------------------
# Epoch 96
# Training loss: 0.02743235
# -------------------------------
# Epoch 97
# Training loss: 0.02739598
# -------------------------------
# Epoch 98
# Training loss: 0.02748621
# -------------------------------
# Epoch 99
# Training loss: 0.02747283
# -------------------------------
# Epoch 100
# Training loss: 0.02750433
# -------------------------------
# Epoch 101
# Training loss: 0.02742497
# -------------------------------
# Epoch 102
# Training loss: 0.02750194
# -------------------------------
# Epoch 103
# Training loss: 0.02743864
# -------------------------------
# Epoch 104
# Training loss: 0.02753013
# -------------------------------
# Epoch 105
# Training loss: 0.02734177
# -------------------------------
# Epoch 106
# Training loss: 0.02738392
# -------------------------------
# Epoch 107
# Training loss: 0.02735999
# -------------------------------
# Epoch 108
# Training loss: 0.02732962
# -------------------------------
# Epoch 109
# Training loss: 0.02737684
# -------------------------------
# Epoch 110
# Training loss: 0.02734576
# -------------------------------
# Epoch 111
# Training loss: 0.02735197
# -------------------------------
# Epoch 112
# Training loss: 0.02731760
# -------------------------------
# Epoch 113
# Training loss: 0.02738975
# -------------------------------
# Epoch 114
# Training loss: 0.02740355
# -------------------------------
# Epoch 115
# Training loss: 0.02738582
# -------------------------------
# Epoch 116
# Training loss: 0.02737104
# -------------------------------
# Epoch 117
# Training loss: 0.02739916
# -------------------------------
# Epoch 118
# Training loss: 0.02736861
# -------------------------------
# Epoch 119
# Training loss: 0.02739524
# -------------------------------
# Epoch 120
# Training loss: 0.02732951
# -------------------------------
# Epoch 121
# Training loss: 0.02741383
# -------------------------------
# Epoch 122
# Training loss: 0.02735474
# -------------------------------
# Epoch 123
# Training loss: 0.02741459
# -------------------------------
# Epoch 124
# Training loss: 0.02733649
# -------------------------------
# Epoch 125
# Training loss: 0.02730637
# -------------------------------
# Epoch 126
# Training loss: 0.02735886
# -------------------------------
# Epoch 127
# Training loss: 0.02733765
# -------------------------------
# Epoch 128
# Training loss: 0.02734808
# -------------------------------
# Epoch 129
# Training loss: 0.02735300
# -------------------------------
# Epoch 130
# Training loss: 0.02734428
# -------------------------------
# Epoch 131
# Training loss: 0.02735071
# -------------------------------
# Epoch 132
# Training loss: 0.02734461
# -------------------------------
# Epoch 133
# Training loss: 0.02736068
# -------------------------------
# Epoch 134
# Training loss: 0.02733975
# -------------------------------
# Epoch 135
# Training loss: 0.02736380
# -------------------------------
# Epoch 136
# Training loss: 0.02732985
# -------------------------------
# Epoch 137
# Training loss: 0.02731348
# -------------------------------
# Epoch 138
# Training loss: 0.02733233
# -------------------------------
# Epoch 139
# Training loss: 0.02731435
# -------------------------------
# Epoch 140
# Training loss: 0.02733525
# -------------------------------
# Epoch 141
# Training loss: 0.02731950
# -------------------------------
# Epoch 142
# Training loss: 0.02731737
# -------------------------------
# Epoch 143
# Training loss: 0.02732760
# -------------------------------
# Epoch 144
# Training loss: 0.02734117
# -------------------------------
# Epoch 145
# Training loss: 0.02733468
# -------------------------------
# Epoch 146
# Training loss: 0.02731705
# -------------------------------
# Epoch 147
# Training loss: 0.02730368
# -------------------------------
# Epoch 148
# Training loss: 0.02731957
# -------------------------------
# Epoch 149
# Training loss: 0.02731568
# -------------------------------
# Epoch 150
# Training loss: 0.02732201
# -------------------------------
# Epoch 151
# Training loss: 0.02732614
# -------------------------------
# Epoch 152
# Training loss: 0.02732923
# -------------------------------
# Epoch 153
# Training loss: 0.02732634
# -------------------------------
# Epoch 154
# Training loss: 0.02730611
# -------------------------------
# Epoch 155
# Training loss: 0.02731615
# -------------------------------
# Epoch 156
# Training loss: 0.02731275
# -------------------------------
# Epoch 157
# Training loss: 0.02732987
# -------------------------------
# Epoch 158
# Training loss: 0.02733102
# -------------------------------
# Epoch 159
# Training loss: 0.02733064
# -------------------------------
# Epoch 160
# Training loss: 0.02732460
# -------------------------------
# Epoch 161
# Training loss: 0.02732482
# -------------------------------
# Epoch 162
# Training loss: 0.02731816
# -------------------------------
# Epoch 163
# Training loss: 0.02732620
# -------------------------------
# Epoch 164
# Training loss: 0.02731922
# -------------------------------
# Epoch 165
# Training loss: 0.02732375
# -------------------------------
# Epoch 166
# Training loss: 0.02731383
# -------------------------------
# Epoch 167
# Training loss: 0.02732006
# -------------------------------
# Epoch 168
# Training loss: 0.02732557
# -------------------------------
# Epoch 169
# Training loss: 0.02732204
# -------------------------------
# Epoch 170
# Training loss: 0.02732250
# -------------------------------
# Epoch 171
# Training loss: 0.02731752
# -------------------------------
# Epoch 172
# Training loss: 0.02732060
# -------------------------------
# Epoch 173
# Training loss: 0.02732872
# -------------------------------
# Epoch 174
# Training loss: 0.02732516
# -------------------------------
# Epoch 175
# Training loss: 0.02731700
# -------------------------------
# Epoch 176
# Training loss: 0.02732052
# -------------------------------
# Epoch 177
# Training loss: 0.02732642
# Early stopping
# Done!
# -------------------------------
# Epoch 1
# Training loss: 0.09416554
# -------------------------------
# Epoch 2
# Training loss: 0.05868759
# -------------------------------
# Epoch 3
# Training loss: 0.05008234
# -------------------------------
# Epoch 4
# Training loss: 0.04088976
# -------------------------------
# Epoch 5
# Training loss: 0.03855842
# -------------------------------
# Epoch 6
# Training loss: 0.03495893
# -------------------------------
# Epoch 7
# Training loss: 0.03275994
# -------------------------------
# Epoch 8
# Training loss: 0.03054670
# -------------------------------
# Epoch 9
# Training loss: 0.03021701
# -------------------------------
# Epoch 10
# Training loss: 0.02907182
# -------------------------------
# Epoch 11
# Training loss: 0.02791108
# -------------------------------
# Epoch 12
# Training loss: 0.02638037
# -------------------------------
# Epoch 13
# Training loss: 0.02612055
# -------------------------------
# Epoch 14
# Training loss: 0.02552079
# -------------------------------
# Epoch 15
# Training loss: 0.02509459
# -------------------------------
# Epoch 16
# Training loss: 0.02442647
# -------------------------------
# Epoch 17
# Training loss: 0.02427754
# -------------------------------
# Epoch 18
# Training loss: 0.02403973
# -------------------------------
# Epoch 19
# Training loss: 0.02310013
# -------------------------------
# Epoch 20
# Training loss: 0.02328970
# -------------------------------
# Epoch 21
# Training loss: 0.02376076
# -------------------------------
# Epoch 22
# Training loss: 0.02224868
# -------------------------------
# Epoch 23
# Training loss: 0.02240202
# -------------------------------
# Epoch 24
# Training loss: 0.02288713
# -------------------------------
# Epoch 25
# Training loss: 0.02300857
# -------------------------------
# Epoch 26
# Training loss: 0.02240946
# -------------------------------
# Epoch 27
# Training loss: 0.02163413
# -------------------------------
# Epoch 28
# Training loss: 0.02164593
# -------------------------------
# Epoch 29
# Training loss: 0.02153495
# -------------------------------
# Epoch 30
# Training loss: 0.02183986
# -------------------------------
# Epoch 31
# Training loss: 0.02108363
# -------------------------------
# Epoch 32
# Training loss: 0.02070617
# -------------------------------
# Epoch 33
# Training loss: 0.02053382
# -------------------------------
# Epoch 34
# Training loss: 0.02050118
# -------------------------------
# Epoch 35
# Training loss: 0.02084877
# -------------------------------
# Epoch 36
# Training loss: 0.02121196
# -------------------------------
# Epoch 37
# Training loss: 0.02035617
# -------------------------------
# Epoch 38
# Training loss: 0.02044770
# -------------------------------
# Epoch 39
# Training loss: 0.02070495
# -------------------------------
# Epoch 40
# Training loss: 0.02037461
# -------------------------------
# Epoch 41
# Training loss: 0.02048059
# -------------------------------
# Epoch 42
# Training loss: 0.02068317
# -------------------------------
# Epoch 43
# Training loss: 0.02042361
# -------------------------------
# Epoch 44
# Training loss: 0.02065763
# -------------------------------
# Epoch 45
# Training loss: 0.02013623
# -------------------------------
# Epoch 46
# Training loss: 0.01986490
# -------------------------------
# Epoch 47
# Training loss: 0.01996743
# -------------------------------
# Epoch 48
# Training loss: 0.01972278
# -------------------------------
# Epoch 49
# Training loss: 0.01982609
# -------------------------------
# Epoch 50
# Training loss: 0.01987697
# -------------------------------
# Epoch 51
# Training loss: 0.01985937
# -------------------------------
# Epoch 52
# Training loss: 0.01953435
# -------------------------------
# Epoch 53
# Training loss: 0.01947481
# -------------------------------
# Epoch 54
# Training loss: 0.01953003
# -------------------------------
# Epoch 55
# Training loss: 0.01904834
# -------------------------------
# Epoch 56
# Training loss: 0.01934193
# -------------------------------
# Epoch 57
# Training loss: 0.01939042
# -------------------------------
# Epoch 58
# Training loss: 0.01934294
# -------------------------------
# Epoch 59
# Training loss: 0.01930448
# -------------------------------
# Epoch 60
# Training loss: 0.01940577
# -------------------------------
# Epoch 61
# Training loss: 0.01918668
# -------------------------------
# Epoch 62
# Training loss: 0.01964057
# -------------------------------
# Epoch 63
# Training loss: 0.01943277
# -------------------------------
# Epoch 64
# Training loss: 0.01901731
# -------------------------------
# Epoch 65
# Training loss: 0.01909122
# -------------------------------
# Epoch 66
# Training loss: 0.01952155
# -------------------------------
# Epoch 67
# Training loss: 0.01954786
# -------------------------------
# Epoch 68
# Training loss: 0.01916592
# -------------------------------
# Epoch 69
# Training loss: 0.01920291
# -------------------------------
# Epoch 70
# Training loss: 0.01900016
# -------------------------------
# Epoch 71
# Training loss: 0.01903165
# -------------------------------
# Epoch 72
# Training loss: 0.01992669
# -------------------------------
# Epoch 73
# Training loss: 0.01925941
# -------------------------------
# Epoch 74
# Training loss: 0.01915376
# -------------------------------
# Epoch 75
# Training loss: 0.01903239
# -------------------------------
# Epoch 76
# Training loss: 0.01981907
# -------------------------------
# Epoch 77
# Training loss: 0.01883092
# -------------------------------
# Epoch 78
# Training loss: 0.01885843
# -------------------------------
# Epoch 79
# Training loss: 0.01883375
# -------------------------------
# Epoch 80
# Training loss: 0.01889735
# -------------------------------
# Epoch 81
# Training loss: 0.01894311
# -------------------------------
# Epoch 82
# Training loss: 0.01921122
# -------------------------------
# Epoch 83
# Training loss: 0.01859775
# -------------------------------
# Epoch 84
# Training loss: 0.01943263
# -------------------------------
# Epoch 85
# Training loss: 0.01896510
# -------------------------------
# Epoch 86
# Training loss: 0.01863775
# -------------------------------
# Epoch 87
# Training loss: 0.01888720
# -------------------------------
# Epoch 88
# Training loss: 0.01894446
# -------------------------------
# Epoch 89
# Training loss: 0.01888147
# -------------------------------
# Epoch 90
# Training loss: 0.01872882
# -------------------------------
# Epoch 91
# Training loss: 0.01906922
# -------------------------------
# Epoch 92
# Training loss: 0.01877260
# -------------------------------
# Epoch 93
# Training loss: 0.01863528
# -------------------------------
# Epoch 94
# Training loss: 0.01861650
# -------------------------------
# Epoch 95
# Training loss: 0.01814188
# -------------------------------
# Epoch 96
# Training loss: 0.01804970
# -------------------------------
# Epoch 97
# Training loss: 0.01830315
# -------------------------------
# Epoch 98
# Training loss: 0.01823448
# -------------------------------
# Epoch 99
# Training loss: 0.01817575
# -------------------------------
# Epoch 100
# Training loss: 0.01818655
# -------------------------------
# Epoch 101
# Training loss: 0.01814433
# -------------------------------
# Epoch 102
# Training loss: 0.01817177
# -------------------------------
# Epoch 103
# Training loss: 0.01816237
# -------------------------------
# Epoch 104
# Training loss: 0.01813542
# -------------------------------
# Epoch 105
# Training loss: 0.01820049
# -------------------------------
# Epoch 106
# Training loss: 0.01816441
# -------------------------------
# Epoch 107
# Training loss: 0.01839620
# -------------------------------
# Epoch 108
# Training loss: 0.01797456
# -------------------------------
# Epoch 109
# Training loss: 0.01788168
# -------------------------------
# Epoch 110
# Training loss: 0.01788126
# -------------------------------
# Epoch 111
# Training loss: 0.01797828
# -------------------------------
# Epoch 112
# Training loss: 0.01790096
# -------------------------------
# Epoch 113
# Training loss: 0.01796948
# -------------------------------
# Epoch 114
# Training loss: 0.01804310
# -------------------------------
# Epoch 115
# Training loss: 0.01793830
# -------------------------------
# Epoch 116
# Training loss: 0.01796691
# -------------------------------
# Epoch 117
# Training loss: 0.01795306
# -------------------------------
# Epoch 118
# Training loss: 0.01796684
# -------------------------------
# Epoch 119
# Training loss: 0.01788392
# -------------------------------
# Epoch 120
# Training loss: 0.01790770
# -------------------------------
# Epoch 121
# Training loss: 0.01788312
# -------------------------------
# Epoch 122
# Training loss: 0.01782311
# -------------------------------
# Epoch 123
# Training loss: 0.01790808
# -------------------------------
# Epoch 124
# Training loss: 0.01786545
# -------------------------------
# Epoch 125
# Training loss: 0.01786429
# -------------------------------
# Epoch 126
# Training loss: 0.01785614
# -------------------------------
# Epoch 127
# Training loss: 0.01782482
# -------------------------------
# Epoch 128
# Training loss: 0.01786839
# -------------------------------
# Epoch 129
# Training loss: 0.01785535
# -------------------------------
# Epoch 130
# Training loss: 0.01787415
# -------------------------------
# Epoch 131
# Training loss: 0.01786080
# -------------------------------
# Epoch 132
# Training loss: 0.01789607
# -------------------------------
# Epoch 133
# Training loss: 0.01787138
# -------------------------------
# Epoch 134
# Training loss: 0.01783747
# -------------------------------
# Epoch 135
# Training loss: 0.01783186
# -------------------------------
# Epoch 136
# Training loss: 0.01784634
# -------------------------------
# Epoch 137
# Training loss: 0.01784561
# -------------------------------
# Epoch 138
# Training loss: 0.01783984
# -------------------------------
# Epoch 139
# Training loss: 0.01787094
# -------------------------------
# Epoch 140
# Training loss: 0.01785471
# -------------------------------
# Epoch 141
# Training loss: 0.01786311
# -------------------------------
# Epoch 142
# Training loss: 0.01783664
# -------------------------------
# Epoch 143
# Training loss: 0.01785143
# -------------------------------
# Epoch 144
# Training loss: 0.01784661
# -------------------------------
# Epoch 145
# Training loss: 0.01783906
# -------------------------------
# Epoch 146
# Training loss: 0.01782997
# -------------------------------
# Epoch 147
# Training loss: 0.01784269
# -------------------------------
# Epoch 148
# Training loss: 0.01782421
# -------------------------------
# Epoch 149
# Training loss: 0.01783294
# -------------------------------
# Epoch 150
# Training loss: 0.01782443
# -------------------------------
# Epoch 151
# Training loss: 0.01783875
# -------------------------------
# Epoch 152
# Training loss: 0.01782367
# Early stopping
# Done!

# %%
orders = range(1,5)
photocounts = [2**i for i in range(6, 12)]

fids = torch.empty(50,len(orders),len(photocounts))

with h5py.File('../../Data/Processed/pure_photocount.h5', 'r') as f:
    for order in orders:
        labels = torch.from_numpy(f[f'labels_order{order}'][:50]).to(device)
        labels = torch.cat([torch.real(labels), torch.imag(labels)], dim=1)
        for (k,n) in enumerate(photocounts):
            images = format_data(f[f'images_order{order}/{n}_photocounts'][:].astype(np.float32))
            model = torch.load(f"../../Results/MachineLearningModels/Photocount/Pure_Order{order}/{n}_photocounts/checkpoint.pt")
            #model.eval()

            with torch.no_grad():
                fids[:,order-1,k] = 1 - training.fidelity_loss(model(images),labels)

fids = fids.numpy()
fids.mean(axis=0)
# Out:
# array([[0.9638479 , 0.9766399 , 0.9872512 , 0.99163824, 0.9944772 ,
#         0.9952853 ],
#        [0.92798203, 0.9626988 , 0.97369117, 0.9836429 , 0.9846523 ,
#         0.98788923],
#        [0.8014133 , 0.8705011 , 0.92280966, 0.9441836 , 0.9686382 ,
#         0.9790116 ],
#        [0.69152784, 0.77247965, 0.85966736, 0.89261633, 0.92167693,
#         0.94233674]], dtype=float32)

# %%
with h5py.File('../../Results/Photocount/machine_learning.h5', 'w') as f:
    f.create_dataset('fids', data=fids.mean(axis=0))
    f.create_dataset('fids_std', data=fids.std(axis=0))
