# %%
import torch
from torch import nn
from torch.optim import lr_scheduler
from torch.utils.data import DataLoader, TensorDataset
from torch.utils.tensorboard import SummaryWriter
import structured_light_tomography.models as models
import structured_light_tomography.training as training
import structured_light_tomography.dataset_generation as dg
import structured_light_tomography.photocount_treatment as pt
from torchvision.transforms import v2
import numpy as np
import matplotlib.pyplot as plts
from os.path import join
import torchvision
import torch.nn.functional as F
import h5py
import matplotlib.pyplot as plt
from torch.utils.data import random_split
from structured_light_tomography.training import fidelity

device = ("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using {device} device")

def format_data(x):
    mean = [x[:, n, :, :].mean() for n in range(x.shape[1])]
    std = [x[:, n, :, :].std() for n in range(x.shape[1])]

    X = v2.Compose([
            torch.from_numpy,
            v2.Normalize(mean=mean, std=std),
            v2.Resize((64, 64)),
        ])(x).to(device)
    return X
# Out:
# Using cuda device

# %%
orders = range(1,6)

# %%
for order in orders:
    with h5py.File('TrainingData/intense_mixed.h5', 'r') as f:
            x = f[f'x_order{order}'][:]
            y = f[f'y_order{order}'][:]
            
    X = format_data(x)
    Y = torch.from_numpy(y).to(device)

    dset = TensorDataset(X, Y)

    train_size = int(0.85 * len(dset))
    test_size = len(dset) - train_size

    train_dataset, test_dataset = random_split(dset, [train_size, test_size])
    train_loader = DataLoader(train_dataset, batch_size=256, shuffle=True)
    test_loader = DataLoader(test_dataset, batch_size=256)

    L = x.shape[2]
    loss_fn = torch.nn.MSELoss()
    n_channels = 2
    n_classes = (order+1)**2-1

    model = models.ConvNet(L,L,n_channels, n_classes,[24,40,35],5,nn.ELU,[120,80,40]).to(device)

    optimizer = torch.optim.Adam(model.parameters(), amsgrad=True)

    save_path = f"runs/Mixed/Order{order}"

    writer = SummaryWriter(save_path)
    early_stopping = training.EarlyStopping(patience=30,save_path=save_path)
    for t in range(200):
        epoch = t+1
        print(f"-------------------------------\nEpoch {epoch}")
        training.train(model, train_loader, loss_fn, optimizer, device)
        val_loss = training.test(model, test_loader, loss_fn, device, epoch, writer, verbose=True)
        early_stopping(val_loss, model)

        if early_stopping.early_stop:
            print("Early stopping")
            break
    print("Done!")
    writer.close()
# Out:
# /home/marcsgil/Desktop/structured_light_tomography/.venv/lib/python3.10/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# -------------------------------
# Epoch 1
# Training loss: 0.00385541
# -------------------------------
# Epoch 2
# Training loss: 0.00313362
# -------------------------------
# Epoch 3
# Training loss: 0.00290820
# -------------------------------
# Epoch 4
# Training loss: 0.00272845
# -------------------------------
# Epoch 5
# Training loss: 0.00238686
# -------------------------------
# Epoch 6
# Training loss: 0.00198748
# -------------------------------
# Epoch 7
# Training loss: 0.00221817
# -------------------------------
# Epoch 8
# Training loss: 0.00242005
# -------------------------------
# Epoch 9
# Training loss: 0.00212049
# -------------------------------
# Epoch 10
# Training loss: 0.00178012
# -------------------------------
# Epoch 11
# Training loss: 0.00199584
# -------------------------------
# Epoch 12
# Training loss: 0.00209538
# -------------------------------
# Epoch 13
# Training loss: 0.00285449
# -------------------------------
# Epoch 14
# Training loss: 0.00168778
# -------------------------------
# Epoch 15
# Training loss: 0.00168832
# -------------------------------
# Epoch 16
# Training loss: 0.00145640
# -------------------------------
# Epoch 17
# Training loss: 0.00148609
# -------------------------------
# Epoch 18
# Training loss: 0.00172259
# -------------------------------
# Epoch 19
# Training loss: 0.00147159
# -------------------------------
# Epoch 20
# Training loss: 0.00158971
# -------------------------------
# Epoch 21
# Training loss: 0.00139425
# -------------------------------
# Epoch 22
# Training loss: 0.00149279
# -------------------------------
# Epoch 23
# Training loss: 0.00142842
# -------------------------------
# Epoch 24
# Training loss: 0.00154018
# -------------------------------
# Epoch 25
# Training loss: 0.00161393
# -------------------------------
# Epoch 26
# Training loss: 0.00160333
# -------------------------------
# Epoch 27
# Training loss: 0.00136187
# -------------------------------
# Epoch 28
# Training loss: 0.00141183
# -------------------------------
# Epoch 29
# Training loss: 0.00152571
# -------------------------------
# Epoch 30
# Training loss: 0.00134682
# -------------------------------
# Epoch 31
# Training loss: 0.00130969
# -------------------------------
# Epoch 32
# Training loss: 0.00139912
# -------------------------------
# Epoch 33
# Training loss: 0.00129608
# -------------------------------
# Epoch 34
# Training loss: 0.00147886
# -------------------------------
# Epoch 35
# Training loss: 0.00127138
# -------------------------------
# Epoch 36
# Training loss: 0.00129870
# -------------------------------
# Epoch 37
# Training loss: 0.00132978
# -------------------------------
# Epoch 38
# Training loss: 0.00131370
# -------------------------------
# Epoch 39
# Training loss: 0.00133437
# -------------------------------
# Epoch 40
# Training loss: 0.00137352
# -------------------------------
# Epoch 41
# Training loss: 0.00133523
# -------------------------------
# Epoch 42
# Training loss: 0.00130391
# -------------------------------
# Epoch 43
# Training loss: 0.00127935
# -------------------------------
# Epoch 44
# Training loss: 0.00135855
# -------------------------------
# Epoch 45
# Training loss: 0.00142097
# -------------------------------
# Epoch 46
# Training loss: 0.00132938
# -------------------------------
# Epoch 47
# Training loss: 0.00128914
# -------------------------------
# Epoch 48
# Training loss: 0.00127801
# -------------------------------
# Epoch 49
# Training loss: 0.00128182
# -------------------------------
# Epoch 50
# Training loss: 0.00145112
# -------------------------------
# Epoch 51
# Training loss: 0.00134765
# -------------------------------
# Epoch 52
# Training loss: 0.00138217
# -------------------------------
# Epoch 53
# Training loss: 0.00125397
# -------------------------------
# Epoch 54
# Training loss: 0.00143173
# -------------------------------
# Epoch 55
# Training loss: 0.00132284
# -------------------------------
# Epoch 56
# Training loss: 0.00128266
# -------------------------------
# Epoch 57
# Training loss: 0.00125218
# -------------------------------
# Epoch 58
# Training loss: 0.00137470
# -------------------------------
# Epoch 59
# Training loss: 0.00124208
# -------------------------------
# Epoch 60
# Training loss: 0.00129739
# -------------------------------
# Epoch 61
# Training loss: 0.00130509
# -------------------------------
# Epoch 62
# Training loss: 0.00130266
# -------------------------------
# Epoch 63
# Training loss: 0.00133136
# -------------------------------
# Epoch 64
# Training loss: 0.00148120
# -------------------------------
# Epoch 65
# Training loss: 0.00136766
# -------------------------------
# Epoch 66
# Training loss: 0.00131821
# -------------------------------
# Epoch 67
# Training loss: 0.00131372
# -------------------------------
# Epoch 68
# Training loss: 0.00131054
# -------------------------------
# Epoch 69
# Training loss: 0.00127466
# -------------------------------
# Epoch 70
# Training loss: 0.00127243
# -------------------------------
# Epoch 71
# Training loss: 0.00135290
# -------------------------------
# Epoch 72
# Training loss: 0.00134773
# -------------------------------
# Epoch 73
# Training loss: 0.00124465
# -------------------------------
# Epoch 74
# Training loss: 0.00133821
# -------------------------------
# Epoch 75
# Training loss: 0.00131616
# -------------------------------
# Epoch 76
# Training loss: 0.00133581
# -------------------------------
# Epoch 77
# Training loss: 0.00129868
# -------------------------------
# Epoch 78
# Training loss: 0.00127726
# -------------------------------
# Epoch 79
# Training loss: 0.00139949
# -------------------------------
# Epoch 80
# Training loss: 0.00124819
# -------------------------------
# Epoch 81
# Training loss: 0.00128166
# -------------------------------
# Epoch 82
# Training loss: 0.00144361
# -------------------------------
# Epoch 83
# Training loss: 0.00133867
# -------------------------------
# Epoch 84
# Training loss: 0.00128110
# -------------------------------
# Epoch 85
# Training loss: 0.00134896
# -------------------------------
# Epoch 86
# Training loss: 0.00127785
# -------------------------------
# Epoch 87
# Training loss: 0.00127795
# -------------------------------
# Epoch 88
# Training loss: 0.00137612
# -------------------------------
# Epoch 89
# Training loss: 0.00147213
# Early stopping
# Done!
# -------------------------------
# Epoch 1
# Training loss: 0.00398340
# -------------------------------
# Epoch 2
# Training loss: 0.00387885
# -------------------------------
# Epoch 3
# Training loss: 0.00334619
# -------------------------------
# Epoch 4
# Training loss: 0.00323291
# -------------------------------
# Epoch 5
# Training loss: 0.00287750
# -------------------------------
# Epoch 6
# Training loss: 0.00315760
# -------------------------------
# Epoch 7
# Training loss: 0.00289746
# -------------------------------
# Epoch 8
# Training loss: 0.00261946
# -------------------------------
# Epoch 9
# Training loss: 0.00267190
# -------------------------------
# Epoch 10
# Training loss: 0.00263746
# -------------------------------
# Epoch 11
# Training loss: 0.00258483
# -------------------------------
# Epoch 12
# Training loss: 0.00255552
# -------------------------------
# Epoch 13
# Training loss: 0.00263410
# -------------------------------
# Epoch 14
# Training loss: 0.00257148
# -------------------------------
# Epoch 15
# Training loss: 0.00256434
# -------------------------------
# Epoch 16
# Training loss: 0.00256846
# -------------------------------
# Epoch 17
# Training loss: 0.00247441
# -------------------------------
# Epoch 18
# Training loss: 0.00254688
# -------------------------------
# Epoch 19
# Training loss: 0.00253076
# -------------------------------
# Epoch 20
# Training loss: 0.00257350
# -------------------------------
# Epoch 21
# Training loss: 0.00261328
# -------------------------------
# Epoch 22
# Training loss: 0.00250457
# -------------------------------
# Epoch 23
# Training loss: 0.00257376
# -------------------------------
# Epoch 24
# Training loss: 0.00253232
# -------------------------------
# Epoch 25
# Training loss: 0.00249945
# -------------------------------
# Epoch 26
# Training loss: 0.00264132
# -------------------------------
# Epoch 27
# Training loss: 0.00255926
# -------------------------------
# Epoch 28
# Training loss: 0.00264331
# -------------------------------
# Epoch 29
# Training loss: 0.00255953
# -------------------------------
# Epoch 30
# Training loss: 0.00256601
# -------------------------------
# Epoch 31
# Training loss: 0.00260303
# -------------------------------
# Epoch 32
# Training loss: 0.00265195
# -------------------------------
# Epoch 33
# Training loss: 0.00256820
# -------------------------------
# Epoch 34
# Training loss: 0.00269227
# -------------------------------
# Epoch 35
# Training loss: 0.00257710
# -------------------------------
# Epoch 36
# Training loss: 0.00268823
# -------------------------------
# Epoch 37
# Training loss: 0.00268302
# -------------------------------
# Epoch 38
# Training loss: 0.00264659
# -------------------------------
# Epoch 39
# Training loss: 0.00263886
# -------------------------------
# Epoch 40
# Training loss: 0.00270647
# -------------------------------
# Epoch 41
# Training loss: 0.00269679
# -------------------------------
# Epoch 42
# Training loss: 0.00263497
# -------------------------------
# Epoch 43
# Training loss: 0.00266129
# -------------------------------
# Epoch 44
# Training loss: 0.00259305
# -------------------------------
# Epoch 45
# Training loss: 0.00274023
# -------------------------------
# Epoch 46
# Training loss: 0.00267421
# -------------------------------
# Epoch 47
# Training loss: 0.00274352
# Early stopping
# Done!
# -------------------------------
# Epoch 1
# Training loss: 0.00226765
# -------------------------------
# Epoch 2
# Training loss: 0.00195566
# -------------------------------
# Epoch 3
# Training loss: 0.00180246
# -------------------------------
# Epoch 4
# Training loss: 0.00171527
# -------------------------------
# Epoch 5
# Training loss: 0.00170451
# -------------------------------
# Epoch 6
# Training loss: 0.00153828
# -------------------------------
# Epoch 7
# Training loss: 0.00151197
# -------------------------------
# Epoch 8
# Training loss: 0.00147104
# -------------------------------
# Epoch 9
# Training loss: 0.00146888
# -------------------------------
# Epoch 10
# Training loss: 0.00144234
# -------------------------------
# Epoch 11
# Training loss: 0.00137457
# -------------------------------
# Epoch 12
# Training loss: 0.00138610
# -------------------------------
# Epoch 13
# Training loss: 0.00136083
# -------------------------------
# Epoch 14
# Training loss: 0.00139378
# -------------------------------
# Epoch 15
# Training loss: 0.00132290
# -------------------------------
# Epoch 16
# Training loss: 0.00137686
# -------------------------------
# Epoch 17
# Training loss: 0.00133491
# -------------------------------
# Epoch 18
# Training loss: 0.00133289
# -------------------------------
# Epoch 19
# Training loss: 0.00134503
# -------------------------------
# Epoch 20
# Training loss: 0.00145804
# -------------------------------
# Epoch 21
# Training loss: 0.00140910
# -------------------------------
# Epoch 22
# Training loss: 0.00135274
# -------------------------------
# Epoch 23
# Training loss: 0.00129385
# -------------------------------
# Epoch 24
# Training loss: 0.00127064
# -------------------------------
# Epoch 25
# Training loss: 0.00140844
# -------------------------------
# Epoch 26
# Training loss: 0.00128358
# -------------------------------
# Epoch 27
# Training loss: 0.00127354
# -------------------------------
# Epoch 28
# Training loss: 0.00127903
# -------------------------------
# Epoch 29
# Training loss: 0.00124819
# -------------------------------
# Epoch 30
# Training loss: 0.00124619
# -------------------------------
# Epoch 31
# Training loss: 0.00130438
# -------------------------------
# Epoch 32
# Training loss: 0.00130851
# -------------------------------
# Epoch 33
# Training loss: 0.00126141
# -------------------------------
# Epoch 34
# Training loss: 0.00125672
# -------------------------------
# Epoch 35
# Training loss: 0.00126341
# -------------------------------
# Epoch 36
# Training loss: 0.00126149
# -------------------------------
# Epoch 37
# Training loss: 0.00125136
# -------------------------------
# Epoch 38
# Training loss: 0.00128556
# -------------------------------
# Epoch 39
# Training loss: 0.00124116
# -------------------------------
# Epoch 40
# Training loss: 0.00137592
# -------------------------------
# Epoch 41
# Training loss: 0.00128905
# -------------------------------
# Epoch 42
# Training loss: 0.00129800
# -------------------------------
# Epoch 43
# Training loss: 0.00124704
# -------------------------------
# Epoch 44
# Training loss: 0.00127735
# -------------------------------
# Epoch 45
# Training loss: 0.00127259
# -------------------------------
# Epoch 46
# Training loss: 0.00125365
# -------------------------------
# Epoch 47
# Training loss: 0.00126855
# -------------------------------
# Epoch 48
# Training loss: 0.00129339
# -------------------------------
# Epoch 49
# Training loss: 0.00125448
# -------------------------------
# Epoch 50
# Training loss: 0.00129006
# -------------------------------
# Epoch 51
# Training loss: 0.00128446
# -------------------------------
# Epoch 52
# Training loss: 0.00126006
# -------------------------------
# Epoch 53
# Training loss: 0.00126354
# -------------------------------
# Epoch 54
# Training loss: 0.00126564
# -------------------------------
# Epoch 55
# Training loss: 0.00127229
# -------------------------------
# Epoch 56
# Training loss: 0.00126648
# -------------------------------
# Epoch 57
# Training loss: 0.00127339
# -------------------------------
# Epoch 58
# Training loss: 0.00131348
# -------------------------------
# Epoch 59
# Training loss: 0.00126387
# -------------------------------
# Epoch 60
# Training loss: 0.00127940
# -------------------------------
# Epoch 61
# Training loss: 0.00128756
# -------------------------------
# Epoch 62
# Training loss: 0.00126871
# -------------------------------
# Epoch 63
# Training loss: 0.00126392
# -------------------------------
# Epoch 64
# Training loss: 0.00125742
# -------------------------------
# Epoch 65
# Training loss: 0.00129350
# -------------------------------
# Epoch 66
# Training loss: 0.00127196
# -------------------------------
# Epoch 67
# Training loss: 0.00126238
# -------------------------------
# Epoch 68
# Training loss: 0.00126837
# -------------------------------
# Epoch 69
# Training loss: 0.00130752
# Early stopping
# Done!
# -------------------------------
# Epoch 1
# Training loss: 0.00173551
# -------------------------------
# Epoch 2
# Training loss: 0.00147167
# -------------------------------
# Epoch 3
# Training loss: 0.00143508
# -------------------------------
# Epoch 4
# Training loss: 0.00133250
# -------------------------------
# Epoch 5
# Training loss: 0.00124580
# -------------------------------
# Epoch 6
# Training loss: 0.00117611
# -------------------------------
# Epoch 7
# Training loss: 0.00126793
# -------------------------------
# Epoch 8
# Training loss: 0.00113553
# -------------------------------
# Epoch 9
# Training loss: 0.00118544
# -------------------------------
# Epoch 10
# Training loss: 0.00110817
# -------------------------------
# Epoch 11
# Training loss: 0.00106253
# -------------------------------
# Epoch 12
# Training loss: 0.00119589
# -------------------------------
# Epoch 13
# Training loss: 0.00107401
# -------------------------------
# Epoch 14
# Training loss: 0.00110907
# -------------------------------
# Epoch 15
# Training loss: 0.00108085
# -------------------------------
# Epoch 16
# Training loss: 0.00099413
# -------------------------------
# Epoch 17
# Training loss: 0.00101477
# -------------------------------
# Epoch 18
# Training loss: 0.00102867
# -------------------------------
# Epoch 19
# Training loss: 0.00101564
# -------------------------------
# Epoch 20
# Training loss: 0.00102649
# -------------------------------
# Epoch 21
# Training loss: 0.00099050
# -------------------------------
# Epoch 22
# Training loss: 0.00101516
# -------------------------------
# Epoch 23
# Training loss: 0.00103189
# -------------------------------
# Epoch 24
# Training loss: 0.00100413
# -------------------------------
# Epoch 25
# Training loss: 0.00096365
# -------------------------------
# Epoch 26
# Training loss: 0.00097177
# -------------------------------
# Epoch 27
# Training loss: 0.00099288
# -------------------------------
# Epoch 28
# Training loss: 0.00098928
# -------------------------------
# Epoch 29
# Training loss: 0.00098416
# -------------------------------
# Epoch 30
# Training loss: 0.00098429
# -------------------------------
# Epoch 31
# Training loss: 0.00097378
# -------------------------------
# Epoch 32
# Training loss: 0.00098683
# -------------------------------
# Epoch 33
# Training loss: 0.00098456
# -------------------------------
# Epoch 34
# Training loss: 0.00102546
# -------------------------------
# Epoch 35
# Training loss: 0.00095695
# -------------------------------
# Epoch 36
# Training loss: 0.00096408
# -------------------------------
# Epoch 37
# Training loss: 0.00095670
# -------------------------------
# Epoch 38
# Training loss: 0.00095484
# -------------------------------
# Epoch 39
# Training loss: 0.00097402
# -------------------------------
# Epoch 40
# Training loss: 0.00093965
# -------------------------------
# Epoch 41
# Training loss: 0.00094719
# -------------------------------
# Epoch 42
# Training loss: 0.00096409
# -------------------------------
# Epoch 43
# Training loss: 0.00092939
# -------------------------------
# Epoch 44
# Training loss: 0.00096215
# -------------------------------
# Epoch 45
# Training loss: 0.00093335
# -------------------------------
# Epoch 46
# Training loss: 0.00093421
# -------------------------------
# Epoch 47
# Training loss: 0.00094360
# -------------------------------
# Epoch 48
# Training loss: 0.00092488
# -------------------------------
# Epoch 49
# Training loss: 0.00093849
# -------------------------------
# Epoch 50
# Training loss: 0.00093926
# -------------------------------
# Epoch 51
# Training loss: 0.00093765
# -------------------------------
# Epoch 52
# Training loss: 0.00092095
# -------------------------------
# Epoch 53
# Training loss: 0.00095599
# -------------------------------
# Epoch 54
# Training loss: 0.00092114
# -------------------------------
# Epoch 55
# Training loss: 0.00094079
# -------------------------------
# Epoch 56
# Training loss: 0.00091773
# -------------------------------
# Epoch 57
# Training loss: 0.00095557
# -------------------------------
# Epoch 58
# Training loss: 0.00093487
# -------------------------------
# Epoch 59
# Training loss: 0.00094509
# -------------------------------
# Epoch 60
# Training loss: 0.00093615
# -------------------------------
# Epoch 61
# Training loss: 0.00096601
# -------------------------------
# Epoch 62
# Training loss: 0.00093656
# -------------------------------
# Epoch 63
# Training loss: 0.00094355
# -------------------------------
# Epoch 64
# Training loss: 0.00093227
# -------------------------------
# Epoch 65
# Training loss: 0.00091846
# -------------------------------
# Epoch 66
# Training loss: 0.00092049
# -------------------------------
# Epoch 67
# Training loss: 0.00093080
# -------------------------------
# Epoch 68
# Training loss: 0.00093681
# -------------------------------
# Epoch 69
# Training loss: 0.00094804
# -------------------------------
# Epoch 70
# Training loss: 0.00096113
# -------------------------------
# Epoch 71
# Training loss: 0.00093596
# -------------------------------
# Epoch 72
# Training loss: 0.00090703
# -------------------------------
# Epoch 73
# Training loss: 0.00093531
# -------------------------------
# Epoch 74
# Training loss: 0.00091867
# -------------------------------
# Epoch 75
# Training loss: 0.00091845
# -------------------------------
# Epoch 76
# Training loss: 0.00092786
# -------------------------------
# Epoch 77
# Training loss: 0.00094081
# -------------------------------
# Epoch 78
# Training loss: 0.00093314
# -------------------------------
# Epoch 79
# Training loss: 0.00092093
# -------------------------------
# Epoch 80
# Training loss: 0.00092158
# -------------------------------
# Epoch 81
# Training loss: 0.00091165
# -------------------------------
# Epoch 82
# Training loss: 0.00092198
# -------------------------------
# Epoch 83
# Training loss: 0.00093160
# -------------------------------
# Epoch 84
# Training loss: 0.00094729
# -------------------------------
# Epoch 85
# Training loss: 0.00092946
# -------------------------------
# Epoch 86
# Training loss: 0.00094076
# -------------------------------
# Epoch 87
# Training loss: 0.00099164
# -------------------------------
# Epoch 88
# Training loss: 0.00093159
# -------------------------------
# Epoch 89
# Training loss: 0.00092564
# -------------------------------
# Epoch 90
# Training loss: 0.00092869
# -------------------------------
# Epoch 91
# Training loss: 0.00095709
# -------------------------------
# Epoch 92
# Training loss: 0.00093989
# -------------------------------
# Epoch 93
# Training loss: 0.00093440
# -------------------------------
# Epoch 94
# Training loss: 0.00091985
# -------------------------------
# Epoch 95
# Training loss: 0.00092813
# -------------------------------
# Epoch 96
# Training loss: 0.00093635
# -------------------------------
# Epoch 97
# Training loss: 0.00093277
# -------------------------------
# Epoch 98
# Training loss: 0.00093496
# -------------------------------
# Epoch 99
# Training loss: 0.00093674
# -------------------------------
# Epoch 100
# Training loss: 0.00094166
# -------------------------------
# Epoch 101
# Training loss: 0.00094633
# -------------------------------
# Epoch 102
# Training loss: 0.00094790
# Early stopping
# Done!
# -------------------------------
# Epoch 1
# Training loss: 0.00130036
# -------------------------------
# Epoch 2
# Training loss: 0.00107121
# -------------------------------
# Epoch 3
# Training loss: 0.00101099
# -------------------------------
# Epoch 4
# Training loss: 0.00098180
# -------------------------------
# Epoch 5
# Training loss: 0.00095129
# -------------------------------
# Epoch 6
# Training loss: 0.00092821
# -------------------------------
# Epoch 7
# Training loss: 0.00091396
# -------------------------------
# Epoch 8
# Training loss: 0.00097160
# -------------------------------
# Epoch 9
# Training loss: 0.00084695
# -------------------------------
# Epoch 10
# Training loss: 0.00084146
# -------------------------------
# Epoch 11
# Training loss: 0.00084350
# -------------------------------
# Epoch 12
# Training loss: 0.00086854
# -------------------------------
# Epoch 13
# Training loss: 0.00080159
# -------------------------------
# Epoch 14
# Training loss: 0.00077244
# -------------------------------
# Epoch 15
# Training loss: 0.00077384
# -------------------------------
# Epoch 16
# Training loss: 0.00083769
# -------------------------------
# Epoch 17
# Training loss: 0.00075395
# -------------------------------
# Epoch 18
# Training loss: 0.00075073
# -------------------------------
# Epoch 19
# Training loss: 0.00073717
# -------------------------------
# Epoch 20
# Training loss: 0.00074453
# -------------------------------
# Epoch 21
# Training loss: 0.00071092
# -------------------------------
# Epoch 22
# Training loss: 0.00072668
# -------------------------------
# Epoch 23
# Training loss: 0.00073617
# -------------------------------
# Epoch 24
# Training loss: 0.00071689
# -------------------------------
# Epoch 25
# Training loss: 0.00070738
# -------------------------------
# Epoch 26
# Training loss: 0.00069840
# -------------------------------
# Epoch 27
# Training loss: 0.00070336
# -------------------------------
# Epoch 28
# Training loss: 0.00068890
# -------------------------------
# Epoch 29
# Training loss: 0.00069078
# -------------------------------
# Epoch 30
# Training loss: 0.00072967
# -------------------------------
# Epoch 31
# Training loss: 0.00066614
# -------------------------------
# Epoch 32
# Training loss: 0.00068000
# -------------------------------
# Epoch 33
# Training loss: 0.00070576
# -------------------------------
# Epoch 34
# Training loss: 0.00066832
# -------------------------------
# Epoch 35
# Training loss: 0.00069980
# -------------------------------
# Epoch 36
# Training loss: 0.00070942
# -------------------------------
# Epoch 37
# Training loss: 0.00068962
# -------------------------------
# Epoch 38
# Training loss: 0.00068016
# -------------------------------
# Epoch 39
# Training loss: 0.00066621
# -------------------------------
# Epoch 40
# Training loss: 0.00067770
# -------------------------------
# Epoch 41
# Training loss: 0.00066949
# -------------------------------
# Epoch 42
# Training loss: 0.00065945
# -------------------------------
# Epoch 43
# Training loss: 0.00070084
# -------------------------------
# Epoch 44
# Training loss: 0.00065526
# -------------------------------
# Epoch 45
# Training loss: 0.00067972
# -------------------------------
# Epoch 46
# Training loss: 0.00070265
# -------------------------------
# Epoch 47
# Training loss: 0.00066052
# -------------------------------
# Epoch 48
# Training loss: 0.00067489
# -------------------------------
# Epoch 49
# Training loss: 0.00068057
# -------------------------------
# Epoch 50
# Training loss: 0.00067815
# -------------------------------
# Epoch 51
# Training loss: 0.00065715
# -------------------------------
# Epoch 52
# Training loss: 0.00067509
# -------------------------------
# Epoch 53
# Training loss: 0.00063750
# -------------------------------
# Epoch 54
# Training loss: 0.00067927
# -------------------------------
# Epoch 55
# Training loss: 0.00065412
# -------------------------------
# Epoch 56
# Training loss: 0.00067061
# -------------------------------
# Epoch 57
# Training loss: 0.00067293
# -------------------------------
# Epoch 58
# Training loss: 0.00067001
# -------------------------------
# Epoch 59
# Training loss: 0.00064819
# -------------------------------
# Epoch 60
# Training loss: 0.00065464
# -------------------------------
# Epoch 61
# Training loss: 0.00066505
# -------------------------------
# Epoch 62
# Training loss: 0.00063839
# -------------------------------
# Epoch 63
# Training loss: 0.00065113
# -------------------------------
# Epoch 64
# Training loss: 0.00066311
# -------------------------------
# Epoch 65
# Training loss: 0.00063504
# -------------------------------
# Epoch 66
# Training loss: 0.00066518
# -------------------------------
# Epoch 67
# Training loss: 0.00066701
# -------------------------------
# Epoch 68
# Training loss: 0.00066218
# -------------------------------
# Epoch 69
# Training loss: 0.00064934
# -------------------------------
# Epoch 70
# Training loss: 0.00065566
# -------------------------------
# Epoch 71
# Training loss: 0.00063584
# -------------------------------
# Epoch 72
# Training loss: 0.00062759
# -------------------------------
# Epoch 73
# Training loss: 0.00063038
# -------------------------------
# Epoch 74
# Training loss: 0.00064334
# -------------------------------
# Epoch 75
# Training loss: 0.00065205
# -------------------------------
# Epoch 76
# Training loss: 0.00065116
# -------------------------------
# Epoch 77
# Training loss: 0.00064928
# -------------------------------
# Epoch 78
# Training loss: 0.00063746
# -------------------------------
# Epoch 79
# Training loss: 0.00064305
# -------------------------------
# Epoch 80
# Training loss: 0.00063290
# -------------------------------
# Epoch 81
# Training loss: 0.00065281
# -------------------------------
# Epoch 82
# Training loss: 0.00063748
# -------------------------------
# Epoch 83
# Training loss: 0.00064616
# -------------------------------
# Epoch 84
# Training loss: 0.00064040
# -------------------------------
# Epoch 85
# Training loss: 0.00064140
# -------------------------------
# Epoch 86
# Training loss: 0.00062947
# -------------------------------
# Epoch 87
# Training loss: 0.00062410
# -------------------------------
# Epoch 88
# Training loss: 0.00063597
# -------------------------------
# Epoch 89
# Training loss: 0.00068887
# -------------------------------
# Epoch 90
# Training loss: 0.00063340
# -------------------------------
# Epoch 91
# Training loss: 0.00064040
# -------------------------------
# Epoch 92
# Training loss: 0.00064454
# -------------------------------
# Epoch 93
# Training loss: 0.00064662
# -------------------------------
# Epoch 94
# Training loss: 0.00063015
# -------------------------------
# Epoch 95
# Training loss: 0.00062678
# -------------------------------
# Epoch 96
# Training loss: 0.00063081
# -------------------------------
# Epoch 97
# Training loss: 0.00064317
# -------------------------------
# Epoch 98
# Training loss: 0.00063631
# -------------------------------
# Epoch 99
# Training loss: 0.00062771
# -------------------------------
# Epoch 100
# Training loss: 0.00063259
# -------------------------------
# Epoch 101
# Training loss: 0.00061791
# -------------------------------
# Epoch 102
# Training loss: 0.00061314
# -------------------------------
# Epoch 103
# Training loss: 0.00063023
# -------------------------------
# Epoch 104
# Training loss: 0.00061737
# -------------------------------
# Epoch 105
# Training loss: 0.00061237
# -------------------------------
# Epoch 106
# Training loss: 0.00063999
# -------------------------------
# Epoch 107
# Training loss: 0.00063363
# -------------------------------
# Epoch 108
# Training loss: 0.00063824
# -------------------------------
# Epoch 109
# Training loss: 0.00064404
# -------------------------------
# Epoch 110
# Training loss: 0.00063266
# -------------------------------
# Epoch 111
# Training loss: 0.00064695
# -------------------------------
# Epoch 112
# Training loss: 0.00062839
# -------------------------------
# Epoch 113
# Training loss: 0.00062141
# -------------------------------
# Epoch 114
# Training loss: 0.00064424
# -------------------------------
# Epoch 115
# Training loss: 0.00062012
# -------------------------------
# Epoch 116
# Training loss: 0.00064221
# -------------------------------
# Epoch 117
# Training loss: 0.00062720
# -------------------------------
# Epoch 118
# Training loss: 0.00061617
# -------------------------------
# Epoch 119
# Training loss: 0.00065238
# -------------------------------
# Epoch 120
# Training loss: 0.00062000
# -------------------------------
# Epoch 121
# Training loss: 0.00062406
# -------------------------------
# Epoch 122
# Training loss: 0.00063198
# -------------------------------
# Epoch 123
# Training loss: 0.00062284
# -------------------------------
# Epoch 124
# Training loss: 0.00063508
# -------------------------------
# Epoch 125
# Training loss: 0.00061242
# -------------------------------
# Epoch 126
# Training loss: 0.00068718
# -------------------------------
# Epoch 127
# Training loss: 0.00063217
# -------------------------------
# Epoch 128
# Training loss: 0.00063349
# -------------------------------
# Epoch 129
# Training loss: 0.00062870
# -------------------------------
# Epoch 130
# Training loss: 0.00062142
# -------------------------------
# Epoch 131
# Training loss: 0.00063603
# -------------------------------
# Epoch 132
# Training loss: 0.00062281
# -------------------------------
# Epoch 133
# Training loss: 0.00063130
# -------------------------------
# Epoch 134
# Training loss: 0.00062352
# -------------------------------
# Epoch 135
# Training loss: 0.00062794
# Early stopping
# Done!

# %%
def A(dim, j):
    assert dim > j, "The dimension must be greater than the index."
    D = np.zeros(dim, dtype=np.float32)
    for i in range(j):
        D[i] = 1
    D[j] = -j
    D = D / np.linalg.norm(D)
    return np.diag(D)

def B(dim, j, k):
    B = np.zeros((dim, dim), dtype=np.float32)
    B[j-1, k-1] = 1
    B[k-1, j-1] = 1
    B = (B + B.T) / 2
    B = B / np.linalg.norm(B)
    return B

def C(dim, j, k):
    C = np.zeros((dim, dim), dtype=np.complex64)
    C[j-1, k-1] = 1j
    C[k-1, j-1] = -1j
    C = (C + C.T.conj()) / 2
    C = C / np.linalg.norm(C)
    return C

def get_basis(dim):
    As = np.stack([A(dim, j) for j in range(1, dim)])
    Bs = np.empty((dim * (dim - 1) // 2, dim, dim), dtype=np.float32)
    Cs = np.empty((dim * (dim - 1) // 2, dim, dim), dtype=np.complex64)
    for j in range(1, dim + 1):
        for k in range(0, j):
            Bs[(j - 2) * (j - 1) // 2 + k - 1, :, :] = B(dim, j, k)
            Cs[(j - 2) * (j - 1) // 2 + k - 1, :, :] = C(dim, j, k)
    return np.concatenate((As, Bs, Cs), axis=0)

def real_representation(rhos):
    assert rhos.shape[1] == rhos.shape[2], "The density matrices must be square."
    dim = rhos.shape[1]
    xs = np.empty((rhos.shape[0],dim**2 - 1), dtype=np.float32)
    basis = get_basis(dim)
    for rho, x in zip(rhos,xs):
        for i, b in enumerate(basis):
            x[i] = np.real(np.trace(rho @ b))
    return xs

def complex_representation(xs):
    device = xs.device
    dim = int((xs.size(1) + 1) ** 0.5)
    basis = torch.from_numpy(get_basis(dim)).to(device)

    return torch.stack([torch.eye(dim).to(device) / dim + sum(c * b for c, b in zip(x, basis)) for x in xs])

def fidelity(rhos1, rhos2):
    fids = torch.empty(rhos1.shape[0], dtype=torch.float32)
    for i, (rho1, rho2) in enumerate(zip(rhos1, rhos2)):
        sqrt_rho1 = torch.sqrt(rho1)
        fids[i] = torch.real(torch.trace(torch.sqrt(sqrt_rho1 @ rho2 @ sqrt_rho1)))
    return fids

# %%
rhos = torch.ones(100, 4, 4).to(device)
fidelity(rhos,rhos).shape
# Out:
# torch.Size([100])

# %%
orders = range(1,6)

metric = fidelity
mses = torch.empty(len(orders))


for order in orders:
    with h5py.File('ExperimentalData/Intense/mixed.h5', 'r') as f:
        x_exp = f[f'images_order{order}'][:]
        y_exp = f[f'labels_order{order}'][:]
    
    X_exp = format_data(np.float32(x_exp))
    Y_exp = torch.from_numpy(y_exp).to(device)
    model = torch.load(f"runs/Mixed/Order{order}/checkpoint.pt")

    with torch.no_grad():
        Y_hat = complex_representation(model(X_exp))
        print(Y_exp.shape)
        print(Y_hat.shape)
        mses[order-1] = metric(Y_hat,Y_exp).mean()
        

mses = mses.numpy()
# Out:
# /home/marcsgil/Desktop/structured_light_tomography/.venv/lib/python3.10/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /tmp/ipykernel_42230/1144312176.py:23: RuntimeWarning: invalid value encountered in divide
#   C = C / np.linalg.norm(C)
# torch.Size([100, 2, 2])
# torch.Size([100, 2, 2])
# torch.Size([100, 3, 3])
# torch.Size([100, 3, 3])
# torch.Size([100, 4, 4])
# torch.Size([100, 4, 4])
# torch.Size([100, 5, 5])
# torch.Size([100, 5, 5])
# torch.Size([100, 6, 6])
# torch.Size([100, 6, 6])

# %%
mses
# Out:
# array([1.2491341,       nan,       nan,       nan,       nan],
#       dtype=float32)

# %%
import matplotlib.pyplot as plt
from matplotlib import rc, rcParams
import numpy as np

# Enable LaTeX fonts
rc('text', usetex=True)

# Increase font size
rcParams['font.size'] = 12

# Apply log2 transformation to photocounts
log_photocounts = np.log2(photocounts)

# Set the x and y labels
plt.xlabel("Photocounts")
plt.ylabel("Fidelity")

# Create a list of markers
markers = ['o', '^', 'D', 's']

# Assuming fids is your matrix
for i, line in enumerate(fids, start=1):
    # Use the order index to select a marker from the list
    plt.plot(log_photocounts, line, label=f"Order {i}", marker=markers[i-1])

# Set the xticks to be the original photocounts values
plt.xticks(log_photocounts, photocounts)

# Set the y-axis limits
plt.ylim([0.9, 1])

# Set the y-axis ticks
plt.yticks(np.arange(0.88, 1.01, 0.01))

# Display the labels outside the plotting area
plt.legend(bbox_to_anchor=(1.0, 0.5), loc='center left')

# Display both major and minor grids
plt.grid(which='both')

# Set the minor grid lines to a dotted style and decrease their alpha value
plt.grid(which='minor', linestyle=':', alpha=0.5)

# Save the plot as a PDF file with all elements included
plt.savefig("plots/fidelities_ml.png", bbox_inches='tight')

plt.show()
